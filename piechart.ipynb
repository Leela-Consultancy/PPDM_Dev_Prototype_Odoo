# %% [markdown]
# <a href="https://colab.research.google.com/github/Leela-Consultancy/PPDM_Dev_Prototype_Odoo/blob/main/piechart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Data
categories = ['Category A', 'Category B', 'Category C']
values = [10, 70, 20]

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(values, labels=categories, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart for Data')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Save the pie chart as an image
plt.savefig('pie_chart.png')

# Generate the HTML page
html_content = f'''
<!DOCTYPE html>
<html>
<head>
    <title>Pie Chart</title>
</head>
<body>
    <h1>Pie Chart for Data</h1>
    <img src="pie_chart.png" alt="Pie Chart">
</body>
</html>
'''

# Save the HTML content to a file
with open('pie_chart.html', 'w') as f:
    f.write(html_content)

print("Pie chart and HTML page generated successfully.")
# Out:
# Pie chart and HTML page generated successfully.
